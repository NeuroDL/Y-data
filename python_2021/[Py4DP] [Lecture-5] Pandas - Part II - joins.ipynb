# %% [markdown]
# # Advanced `pandas`
#
# The following notebook is dedicated to more advanved opeartions in Pandas:
#
# - `split-apply-combine` pipeline,
# - operations on string columns (string operations, replacement),
# - joins on Pandas dataframes.

# %%
# %pylab inline
plt.style.use("bmh")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd

# %%
titanic_train = pd.read_csv("titanic/train.csv", index_col="PassengerId")
titanic_test = pd.read_csv("titanic/test.csv", index_col="PassengerId")
titanic = pd.concat([titanic_train, titanic_test], sort=False)

# %%
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# # Joining Pandas dataframes (`JOIN` in Pandas)
#
# We start with a synthetic example:

# %%
a = pd.DataFrame(np.arange(8).reshape((4,2)),
                 columns=["a", "b"],
                 index=["a", "b", "a", "b"])
b = pd.DataFrame(10 + np.arange(4).reshape((4,-1)),
                 columns=["d"],
                 index=["d", "b", "c", "b"])

# %%
a
# Out:
#    a  b
# a  0  1
# b  2  3
# a  4  5
# b  6  7

# %%
b
# Out:
#     d
# d  10
# b  11
# c  12
# b  13

# %%
a.join(b) # default is left join
# Out:
#    a  b     d
# a  0  1   NaN
# a  4  5   NaN
# b  2  3  11.0
# b  2  3  13.0
# b  6  7  11.0
# b  6  7  13.0

# %%
a.join(b, how="inner")
# Out:
#    a  b   d
# b  2  3  11
# b  2  3  13
# b  6  7  11
# b  6  7  13

# %%
a
# Out:
#    a  b
# a  0  1
# b  2  3
# a  4  5
# b  6  7

# %%
b
# Out:
#     d
# d  10
# b  11
# c  12
# b  13

# %%
b.join(a, how="right")
# Out:
#       d  a  b
# a   NaN  0  1
# a   NaN  4  5
# b  11.0  2  3
# b  13.0  2  3
# b  11.0  6  7
# b  13.0  6  7

# %%
a.join(b, how="outer")
# Out:
#      a    b     d
# a  0.0  1.0   NaN
# a  4.0  5.0   NaN
# b  2.0  3.0  11.0
# b  2.0  3.0  13.0
# b  6.0  7.0  11.0
# b  6.0  7.0  13.0
# c  NaN  NaN  12.0
# d  NaN  NaN  10.0

# %% [markdown]
# We can also perform join operation on multi-indexed dataframes:

# %%
c = pd.DataFrame(np.arange(8).reshape((4,2)),
                 columns=["a", "b"],
                 index=pd.MultiIndex.from_tuples([("a", "A"), ("b", "E"), ("a", "Y"), ("b", "R")],
                                                 names=("lower", "upper")))

# %%
c
# Out:
#              a  b
# lower upper
# a     A      0  1
# b     E      2  3
# a     Y      4  5
# b     R      6  7

# %%
a
# Out:
#    a  b
# a  0  1
# b  2  3
# a  4  5
# b  6  7

# %%
c.join(a, on="lower")  # This one will fail
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d014b7ecde93> in <module>
# ----> 1 c.join(a, on="lower")  # This one will fail
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7207         """
#    7208         return self._join_compat(
# -> 7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#    7211
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7230                 right_index=True,
#    7231                 suffixes=(lsuffix, rsuffix),
# -> 7232                 sort=sort,
#    7233             )
#    7234         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     647
#     648         llabels, rlabels = _items_overlap_with_suffix(
# --> 649             ldata.items, lsuf, rdata.items, rsuf
#     650         )
#     651
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    2024         raise ValueError(
#    2025             "columns overlap but no suffix specified: "
# -> 2026             "{rename}".format(rename=to_rename)
#    2027         )
#    2028
#
# ValueError: columns overlap but no suffix specified: Index(['a', 'b'], dtype='object')

# %%
c.join(a, on="lower", rsuffix="_right")
# Out:
#              a  b  a_right  b_right
# lower upper
# a     A      0  1        0        1
#       A      0  1        4        5
# b     E      2  3        2        3
#       E      2  3        6        7
# a     Y      4  5        0        1
#       Y      4  5        4        5
# b     R      6  7        2        3
#       R      6  7        6        7

# %% [markdown]
# # Joining dataframes for EDA

# %% [markdown]
# ## Problem: get (almost) all couples on board

# %%
titanic[["Name", "Sex"]].head()
# Out:
#                                                           Name     Sex
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male

# %%
titanic['wife']=titanic.Name.apply(lambda x: '(' in x)

# %%
titanic.query('wife')
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                 1.0       1
# 4                 1.0       1
# 9                 1.0       3
# 10                1.0       2
# 16                1.0       2
# ...               ...     ...
# 1283              NaN       1
# 1287              NaN       1
# 1289              NaN       1
# 1297              NaN       2
# 1303              NaN       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# ...                                                        ...     ...   ...
# 1283            Lines, Mrs. Ernest H (Elizabeth Lindsey James)  female  51.0
# 1287            Smith, Mrs. Lucien Philip (Mary Eloise Hughes)  female  18.0
# 1289         Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  female  48.0
# 1297              Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0
# 1303           Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0
#
#              SibSp  Parch         Ticket     Fare Cabin Embarked  wife
# PassengerId
# 2                1      0       PC 17599  71.2833   C85        C  True
# 4                1      0         113803  53.1000  C123        S  True
# 9                0      2         347742  11.1333   NaN        S  True
# 10               1      0         237736  30.0708   NaN        C  True
# 16               0      0         248706  16.0000   NaN        S  True
# ...            ...    ...            ...      ...   ...      ...   ...
# 1283             0      1       PC 17592  39.4000   D28        S  True
# 1287             1      0          13695  60.0000   C31        S  True
# 1289             1      1          13567  79.2000   B41        C  True
# 1297             0      0  SC/PARIS 2166  13.8625   D38        C  True
# 1303             1      0          19928  90.0000   C78        Q  True
#
# [221 rows x 12 columns]

# %% [markdown]
# We start by noting the pattern: married females are listed as `<FAMILY_NAME>, Mrs. <HUSBANDS_FIRST_NAME> (<WIFES_FULL_NAME>)`. Let's play with it a bit:

# %%
family_names = (titanic
                .replace(re.compile(r'\s+\(.*\)'), '')
                .replace(re.compile("Mrs."), "Mr."))[["Name", "Sex",'Survived']]

family_names = family_names[(family_names.Sex=="female") & family_names.Name.str.contains("Mr.")]


t2 = titanic.join(family_names.reset_index().set_index("Name")["Survived"],
             on="Name", how="inner", rsuffix="_Spouse")
t2['survival_sum']=t2.Survived+t2.Survived_Spouse
t2.groupby(['Pclass','survival_sum']).size().unstack().apply(lambda x: x/x.sum(),axis=1)
# Out:
# survival_sum       0.0       1.0       2.0
# Pclass
# 1                  NaN  0.470588  0.529412
# 2             0.090909  0.818182  0.090909
# 3             0.500000  0.500000       NaN

# %% [markdown]
# Note, that `PassengerId` **column** was not renamed!

# %%
couples = (titanic.join(family_names
                        .reset_index()
                        .set_index("Name")["PassengerId"],
                        on="Name", how="inner", rsuffix="_Spouse"))

# %%
titanic['is_couple']=[i in couples.PassengerId_Spouse for i in titanic.index.values ]

# %%
titanic.groupby(['wife','is_couple']).size().unstack()
# Out:
# is_couple   False  True
# wife
# False      1002.0   86.0
# True        221.0    NaN

# %%
titanic.sort_values('Name').head(50)
# Out:
#              Survived  Pclass  \
# PassengerId
# 846               0.0       3
# 1284              NaN       3
# 747               0.0       3
# 280               1.0       3
# 1237              NaN       3
# 949               NaN       3
# 309               0.0       2
# 875               1.0       2
# 1143              NaN       3
# 900               NaN       3
# 366               0.0       3
# 402               0.0       3
# 41                0.0       3
# 1199              NaN       3
# 856               1.0       3
# 208               1.0       3
# 970               NaN       2
# 811               0.0       3
# 841               0.0       3
# 211               0.0       3
# 785               0.0       3
# 731               1.0       1
# 5                 0.0       3
# 306               1.0       1
# 298               0.0       1
# 1198              NaN       1
# 499               0.0       1
# 835               0.0       3
# 1102              NaN       3
# 193               1.0       3
# 461               1.0       1
# 851               0.0       3
# 814               0.0       3
# 120               0.0       3
# 69                1.0       3
# 1106              NaN       3
# 542               0.0       3
# 543               0.0       3
# 14                0.0       3
# 147               1.0       3
# 1212              NaN       3
# 611               0.0       3
# 92                0.0       3
# 145               0.0       2
# 1096              NaN       2
# 276               1.0       1
# 807               0.0       1
# 1187              NaN       3
# 1082              NaN       2
# 519               1.0       2
#
#                                                           Name     Sex    Age  \
# PassengerId
# 846                                        Abbing, Mr. Anthony    male  42.00
# 1284                             Abbott, Master. Eugene Joseph    male  13.00
# 747                                Abbott, Mr. Rossmore Edward    male  16.00
# 280                           Abbott, Mrs. Stanton (Rosa Hunt)  female  35.00
# 1237                               Abelseth, Miss. Karen Marie  female  16.00
# 949                              Abelseth, Mr. Olaus Jorgensen    male  25.00
# 309                                        Abelson, Mr. Samuel    male  30.00
# 875                      Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.00
# 1143                  Abrahamsson, Mr. Abraham August Johannes    male  20.00
# 900                  Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.00
# 366                             Adahl, Mr. Mauritz Nils Martin    male  30.00
# 402                                            Adams, Mr. John    male  26.00
# 41              Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.00
# 1199                                 Aks, Master. Philip Frank    male   0.83
# 856                                 Aks, Mrs. Sam (Leah Rosen)  female  18.00
# 208                                Albimona, Mr. Nassef Cassem    male  26.00
# 970                             Aldworth, Mr. Charles Augustus    male  30.00
# 811                                     Alexander, Mr. William    male  26.00
# 841                                Alhomaki, Mr. Ilmari Rudolf    male  20.00
# 211                                             Ali, Mr. Ahmed    male  24.00
# 785                                           Ali, Mr. William    male  25.00
# 731                              Allen, Miss. Elisabeth Walton  female  29.00
# 5                                     Allen, Mr. William Henry    male  35.00
# 306                             Allison, Master. Hudson Trevor    male   0.92
# 298                               Allison, Miss. Helen Loraine  female   2.00
# 1198                      Allison, Mr. Hudson Joshua Creighton    male  30.00
# 499            Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# 835                                     Allum, Mr. Owen George    male  18.00
# 1102                               Andersen, Mr. Albert Karvin    male  32.00
# 193            Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.00
# 461                                        Anderson, Mr. Harry    male  48.00
# 851                    Andersson, Master. Sigvard Harald Elias    male   4.00
# 814                         Andersson, Miss. Ebba Iris Alfrida  female   6.00
# 120                          Andersson, Miss. Ellis Anna Maria  female   2.00
# 69                             Andersson, Miss. Erna Alexandra  female  17.00
# 1106                    Andersson, Miss. Ida Augusta Margareta  female  38.00
# 542                       Andersson, Miss. Ingeborg Constanzia  female   9.00
# 543                          Andersson, Miss. Sigrid Elisabeth  female  11.00
# 14                                 Andersson, Mr. Anders Johan    male  39.00
# 147               Andersson, Mr. August Edvard ("Wennerstrom")    male  27.00
# 1212                               Andersson, Mr. Johan Samuel    male  26.00
# 611          Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.00
# 92                                  Andreasson, Mr. Paul Edvin    male  20.00
# 145                                 Andrew, Mr. Edgardo Samuel    male  18.00
# 1096                                  Andrew, Mr. Frank Thomas    male  25.00
# 276                          Andrews, Miss. Kornelia Theodosia  female  63.00
# 807                                     Andrews, Mr. Thomas Jr    male  39.00
# 1187                                      Angheloff, Mr. Minko    male  26.00
# 1082                                      Angle, Mr. William A    male  34.00
# 519          Angle, Mrs. William A (Florence "Mary" Agnes H...  female  36.00
#
#              SibSp  Parch              Ticket      Fare    Cabin Embarked  \
# PassengerId
# 846              0      0           C.A. 5547    7.5500      NaN        S
# 1284             0      2           C.A. 2673   20.2500      NaN        S
# 747              1      1           C.A. 2673   20.2500      NaN        S
# 280              1      1           C.A. 2673   20.2500      NaN        S
# 1237             0      0              348125    7.6500      NaN        S
# 949              0      0              348122    7.6500    F G63        S
# 309              1      0           P/PP 3381   24.0000      NaN        C
# 875              1      0           P/PP 3381   24.0000      NaN        C
# 1143             0      0    SOTON/O2 3101284    7.9250      NaN        S
# 900              0      0                2657    7.2292      NaN        C
# 366              0      0              C 7076    7.2500      NaN        S
# 402              0      0              341826    8.0500      NaN        S
# 41               1      0                7546    9.4750      NaN        S
# 1199             0      1              392091    9.3500      NaN        S
# 856              0      1              392091    9.3500      NaN        S
# 208              0      0                2699   18.7875      NaN        C
# 970              0      0              248744   13.0000      NaN        S
# 811              0      0                3474    7.8875      NaN        S
# 841              0      0    SOTON/O2 3101287    7.9250      NaN        S
# 211              0      0  SOTON/O.Q. 3101311    7.0500      NaN        S
# 785              0      0  SOTON/O.Q. 3101312    7.0500      NaN        S
# 731              0      0               24160  211.3375       B5        S
# 5                0      0              373450    8.0500      NaN        S
# 306              1      2              113781  151.5500  C22 C26        S
# 298              1      2              113781  151.5500  C22 C26        S
# 1198             1      2              113781  151.5500  C22 C26        S
# 499              1      2              113781  151.5500  C22 C26        S
# 835              0      0                2223    8.3000      NaN        S
# 1102             0      0              C 4001   22.5250      NaN        S
# 193              1      0              350046    7.8542      NaN        S
# 461              0      0               19952   26.5500      E12        S
# 851              4      2              347082   31.2750      NaN        S
# 814              4      2              347082   31.2750      NaN        S
# 120              4      2              347082   31.2750      NaN        S
# 69               4      2             3101281    7.9250      NaN        S
# 1106             4      2              347091    7.7750      NaN        S
# 542              4      2              347082   31.2750      NaN        S
# 543              4      2              347082   31.2750      NaN        S
# 14               1      5              347082   31.2750      NaN        S
# 147              0      0              350043    7.7958      NaN        S
# 1212             0      0              347075    7.7750      NaN        S
# 611              1      5              347082   31.2750      NaN        S
# 92               0      0              347466    7.8542      NaN        S
# 145              0      0              231945   11.5000      NaN        S
# 1096             0      0          C.A. 34050   10.5000      NaN        S
# 276              1      0               13502   77.9583       D7        S
# 807              0      0              112050    0.0000      A36        S
# 1187             0      0              349202    7.8958      NaN        S
# 1082             1      0              226875   26.0000      NaN        S
# 519              1      0              226875   26.0000      NaN        S
#
#               wife  is_couple
# PassengerId
# 846          False      False
# 1284         False      False
# 747          False      False
# 280           True      False
# 1237         False      False
# 949          False      False
# 309          False       True
# 875           True      False
# 1143         False      False
# 900           True      False
# 366          False      False
# 402          False      False
# 41            True      False
# 1199         False      False
# 856           True      False
# 208          False      False
# 970          False      False
# 811          False      False
# 841          False      False
# 211          False      False
# 785          False      False
# 731          False      False
# 5            False      False
# 306          False      False
# 298          False      False
# 1198         False      False
# 499           True      False
# 835          False      False
# 1102         False      False
# 193          False      False
# 461          False      False
# 851          False      False
# 814          False      False
# 120          False      False
# 69           False      False
# 1106         False      False
# 542          False      False
# 543          False      False
# 14           False       True
# 147           True      False
# 1212         False      False
# 611           True      False
# 92           False      False
# 145          False      False
# 1096         False      False
# 276          False      False
# 807          False      False
# 1187         False      False
# 1082         False       True
# 519           True      False

# %%
titanic.query('wife and not is_couple').head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                 1.0       1
# 4                 1.0       1
# 9                 1.0       3
# 10                1.0       2
# 16                1.0       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked  wife  is_couple
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C  True      False
# 4                1      0    113803  53.1000  C123        S  True      False
# 9                0      2    347742  11.1333   NaN        S  True      False
# 10               1      0    237736  30.0708   NaN        C  True      False
# 16               0      0    248706  16.0000   NaN        S  True      False

# %%
couples
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 14                0.0       3     Andersson, Mr. Anders Johan  male  39.0
# 35                0.0       1         Meyer, Mr. Edgar Joseph  male  28.0
# 36                0.0       1  Holverson, Mr. Alexander Oskar  male  42.0
# 63                0.0       1     Harris, Mr. Henry Birkhardt  male  45.0
# 93                0.0       1     Chaffee, Mr. Herbert Fuller  male  46.0
# ...               ...     ...                             ...   ...   ...
# 1208              NaN       1   Spencer, Mr. William Augustus  male  57.0
# 1245              NaN       2              Herman, Mr. Samuel  male  49.0
# 1258              NaN       3               Caram, Mr. Joseph  male   NaN
# 1286              NaN       3        Kink-Heilmann, Mr. Anton  male  29.0
# 1299              NaN       1      Widener, Mr. George Dunton  male  50.0
#
#              SibSp  Parch       Ticket      Fare Cabin Embarked   wife  \
# PassengerId
# 14               1      5       347082   31.2750   NaN        S  False
# 35               1      0     PC 17604   82.1708   NaN        C  False
# 36               1      0       113789   52.0000   NaN        S  False
# 63               1      0        36973   83.4750   C83        S  False
# 93               1      0  W.E.P. 5734   61.1750   E31        S  False
# ...            ...    ...          ...       ...   ...      ...    ...
# 1208             1      0     PC 17569  146.5208   B78        C  False
# 1245             1      2       220845   65.0000   NaN        S  False
# 1258             1      0         2689   14.4583   NaN        C  False
# 1286             3      1       315153   22.0250   NaN        S  False
# 1299             1      1       113503  211.5000   C80        C  False
#
#              PassengerId
# PassengerId
# 14                   611
# 35                   376
# 36                   384
# 63                   231
# 93                   906
# ...                  ...
# 1208                  32
# 1245                 755
# 1258                 579
# 1286                1057
# 1299                1110
#
# [86 rows x 13 columns]

# %%
couples.rename({"PassengerId":"PassengerId_Spouse"},
               axis=1, inplace=True)

# %%
couples.head()
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 14                0.0       3     Andersson, Mr. Anders Johan  male  39.0
# 35                0.0       1         Meyer, Mr. Edgar Joseph  male  28.0
# 36                0.0       1  Holverson, Mr. Alexander Oskar  male  42.0
# 63                0.0       1     Harris, Mr. Henry Birkhardt  male  45.0
# 93                0.0       1     Chaffee, Mr. Herbert Fuller  male  46.0
#
#              SibSp  Parch       Ticket     Fare Cabin Embarked   wife  \
# PassengerId
# 14               1      5       347082  31.2750   NaN        S  False
# 35               1      0     PC 17604  82.1708   NaN        C  False
# 36               1      0       113789  52.0000   NaN        S  False
# 63               1      0        36973  83.4750   C83        S  False
# 93               1      0  W.E.P. 5734  61.1750   E31        S  False
#
#              PassengerId_Spouse
# PassengerId
# 14                          611
# 35                          376
# 36                          384
# 63                          231
# 93                          906

# %%
couples = couples.join(titanic[["Name", "Age"]],
                       on="PassengerId_Spouse", rsuffix="_Spouse")

# %%
couples

# %%
titanic.Pclass.value_counts()

# %%
couples.Pclass.value_counts()

# %%
couples.Sex.value_counts()

# %%
(couples.Age - couples.Age_Spouse).groupby(couples.Pclass).agg(["min", "max", "mean", "median", "std", "count", "size"])

# %%
couples[(couples.Age - couples.Age_Spouse)<0][["PassengerId_Spouse", "Name", "Age", "Name_Spouse", "Age_Spouse"]]

# %%
titanic.loc[742]

# %%
titanic.loc[988]

# %% [markdown]
# Although it's only heuristics, and we may need to dig deeper (e.g., to find some uncommon naming patterns), this is already something. Think on which features you may add to quantify a passenger (say, `is wife/husband on board?`, which may complement `SibSp`).
#
# Think on how you may find entire **families**, and which features you may extract by knowing those. EDA is about your data driven creativity, so - play with it.
#
# P. S. **not a single loop** above.

# %% [markdown]
# ### Intermezzo: on self-joins

# %%
cabin_counts = titanic.Cabin.value_counts()
cabin_counts[cabin_counts>1]
# Out:
# C23 C25 C27        6
# B57 B59 B63 B66    5
# G6                 5
# C22 C26            4
# F33                4
#                   ..
# C52                2
# B49                2
# D17                2
# C54                2
# B45                2
# Name: Cabin, Length: 79, dtype: int64

# %%
cabin_counts = cabin_counts[cabin_counts>1]

# %%
titanic.loc[titanic.Cabin.isin(cabin_counts.index), ["Name", "Cabin"]]#.merge(titanic, on="Cabin", how="inner")
# Out:
#                                                           Name        Cabin
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...          C85
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)         C123
# 7                                      McCarthy, Mr. Timothy J          E46
# 11                             Sandstrom, Miss. Marguerite Rut           G6
# 28                              Fortune, Mr. Charles Alexander  C23 C25 C27
# ...                                                        ...          ...
# 1287            Smith, Mrs. Lucien Philip (Mary Eloise Hughes)          C31
# 1289         Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...          B41
# 1292                                   Bonnell, Miss. Caroline           C7
# 1299                                Widener, Mr. George Dunton          C80
# 1303           Minahan, Mrs. William Edward (Lillian E Thorpe)          C78
#
# [188 rows x 2 columns]

# %%
cabins = (titanic
          .loc[titanic.Cabin.isin(cabin_counts.index),
               ["Name", "Cabin"]]
          .reset_index())

# %%
cabins.merge(cabins, on="Cabin", suffixes=("_first", "_second"))
# Out:
#      PassengerId_first                                         Name_first  \
# 0                    2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1                    2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                 1126                          Cumings, Mr. John Bradley
# 3                 1126                          Cumings, Mr. John Bradley
# 4                    4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ..                 ...                                                ...
# 499               1299                         Widener, Mr. George Dunton
# 500               1144                           Clark, Mr. Walter Miller
# 501               1144                           Clark, Mr. Walter Miller
# 502               1164      Clark, Mrs. Walter Miller (Virginia McDowell)
# 503               1164      Clark, Mrs. Walter Miller (Virginia McDowell)
#
#     Cabin  PassengerId_second  \
# 0     C85                   2
# 1     C85                1126
# 2     C85                   2
# 3     C85                1126
# 4    C123                   4
# ..    ...                 ...
# 499   C80                1299
# 500   C89                1144
# 501   C89                1164
# 502   C89                1144
# 503   C89                1164
#
#                                            Name_second
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1                            Cumings, Mr. John Bradley
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                            Cumings, Mr. John Bradley
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ..                                                 ...
# 499                         Widener, Mr. George Dunton
# 500                           Clark, Mr. Walter Miller
# 501      Clark, Mrs. Walter Miller (Virginia McDowell)
# 502                           Clark, Mr. Walter Miller
# 503      Clark, Mrs. Walter Miller (Virginia McDowell)
#
# [504 rows x 5 columns]

# %%
companions = cabins.merge(cabins, on="Cabin", suffixes=("_first", "_second"))
companions = companions[companions.PassengerId_first != companions.PassengerId_second]

# %%
companions
# Out:
#      PassengerId_first                                         Name_first  \
# 1                    2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                 1126                          Cumings, Mr. John Bradley
# 5                    4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6                  138                        Futrelle, Mr. Jacques Heath
# 9                    7                            McCarthy, Mr. Timothy J
# ..                 ...                                                ...
# 494               1162                       McCaffry, Mr. Thomas Francis
# 497               1110       Widener, Mrs. George Dunton (Eleanor Elkins)
# 498               1299                         Widener, Mr. George Dunton
# 501               1144                           Clark, Mr. Walter Miller
# 502               1164      Clark, Mrs. Walter Miller (Virginia McDowell)
#
#     Cabin  PassengerId_second  \
# 1     C85                1126
# 2     C85                   2
# 5    C123                 138
# 6    C123                   4
# 9     E46                1038
# ..    ...                 ...
# 494    C6                1010
# 497   C80                1299
# 498   C80                1110
# 501   C89                1164
# 502   C89                1144
#
#                                            Name_second
# 1                            Cumings, Mr. John Bradley
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 5                          Futrelle, Mr. Jacques Heath
# 6         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 9                          Hilliard, Mr. Herbert Henry
# ..                                                 ...
# 494                               Beattie, Mr. Thomson
# 497                         Widener, Mr. George Dunton
# 498       Widener, Mrs. George Dunton (Eleanor Elkins)
# 501      Clark, Mrs. Walter Miller (Virginia McDowell)
# 502                           Clark, Mr. Walter Miller
#
# [316 rows x 5 columns]

# %% [markdown]
# We can now clean this up and get another interesting source of information (`travelling with a family member in the same cabin?`, etc.).

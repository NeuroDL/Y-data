# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Question 1

# %%
from scipy.stats import geom

# %%
pa=81/306
pba = geom.pmf(2,1/7.5)
pb_a = geom.pmf(2,1/2.8)
pba*pa/(pba*pa+pb_a*(1-pa))
# Out:
# 0.1533969477137955

# %% [markdown]
# # Question 2

# %% [markdown]
# ![WhatsApp%20Image%202021-11-24%20at%203.12.30%20PM.jpeg](attachment:WhatsApp%20Image%202021-11-24%20at%203.12.30%20PM.jpeg)

# %% [markdown]
# # Question 3

# %%
from scipy.stats import binom

# %%
binom.pmf(60,100,.5)
# Out:
# 0.010843866711637149

# %%
from scipy.stats import ttest_ind_from_stats

# %%
p2,np.sqrt(n2*p2*(2-p2)),n2

# %%
n1=100
n2=150
x1=60
x2=70
p1=x1/n1
p2=x2/n2
ttest_ind_from_stats(p1,np.sqrt(p1*(1-p1)),n1,p2,np.sqrt(p2*(1-p2)),n2,equal_var=True).pvalue/2
# Out:
# 0.019040947208775628

# %%
binom.cdf(70,150,.6)
# Out:
# 0.0006520393985854715
